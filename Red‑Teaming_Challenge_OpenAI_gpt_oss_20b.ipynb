# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishita95-harvad/Red-Teaming-Challenge---OpenAI-gpt-oss-20b/blob/main/Red%E2%80%91Teaming_Challenge_OpenAI_gpt_oss_20b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Red‑Teaming Challenge - OpenAI gpt-oss-20b**
#
# Find any flaws and vulnerabilities in gpt-oss-20b that have not been previously discovered or reported
#
# ![kaggle_101597_logos_header.png](data:image/png;base64,...)

# %% [markdown]
# # **Author:** ISHITA
#
# # **Designation:** SENIOR RESEARCH ANALYST GOOGLE

# %% [markdown]
# ---

# %% [markdown]
# # UPGRADING....
